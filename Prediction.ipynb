# %% [markdown]
# <a href="https://colab.research.google.com/github/gkbichara/Match-Predictor/blob/main/Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# when reading in a CSV file, have to specify which col is the index
matches = pd.read_csv("/content/drive/My Drive/Prediction Project/matches.csv", index_col = 0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2024-08-18  16:30  Premier League  Matchweek 1  Sun  Away      W  2.0  0.0
# 2  2024-08-24  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  1.0
# 3  2024-08-31  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  1.0
# 0  2024-08-17  15:00  Premier League  Matchweek 1  Sat  Away      W  3.0  0.0
# 1  2024-08-24  12:30  Premier League  Matchweek 2  Sat  Home      W  2.0  1.0
#
#          opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 1         Chelsea  ...  Match Report    NaN  11.0  5.0  19.1  0.0  0     0
# 2    Ipswich Town  ...  Match Report    NaN  13.0  4.0  17.8  1.0  1     1
# 3        West Ham  ...  Match Report    NaN  23.0  8.0  15.0  1.0  0     0
# 0         Everton  ...  Match Report    NaN  10.0  5.0  13.8  0.0  0     0
# 1  Manchester Utd  ...  Match Report    NaN  14.0  4.0  14.2  1.0  0     0
#
#   season                      team
# 1   2025           Manchester City
# 2   2025           Manchester City
# 3   2025           Manchester City
# 0   2025  Brighton and Hove Albion
# 1   2025  Brighton and Hove Albion
#
# [5 rows x 28 columns]

# %%
matches.shape
# Out:
# (3100, 28)

# %%
# trying to figure out how many matches we have per team
matches["team"].value_counts()
# Out:
# team
# Manchester City             155
# Newcastle United            155
# Everton                     155
# Crystal Palace              155
# Wolverhampton Wanderers     155
# Brighton and Hove Albion    155
# Manchester United           155
# Chelsea                     155
# West Ham United             155
# Tottenham Hotspur           155
# Arsenal                     155
# Aston Villa                 155
# Liverpool                   155
# Brentford                   117
# Fulham                      117
# Southampton                 117
# Leicester City              117
# Burnley                     114
# Leeds United                114
# Bournemouth                  79
# Nottingham Forest            79
# Sheffield United             76
# Luton Town                   38
# Watford                      38
# Norwich City                 38
# West Bromwich Albion         38
# Ipswich Town                  3
# Name: count, dtype: int64

# %%
# selecting all rows where team is Arsenal
matches[matches["team"] == "Arsenal"]
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2024-08-17  15:00  Premier League   Matchweek 1  Sat  Home      W  2.0
# 1   2024-08-24  17:30  Premier League   Matchweek 2  Sat  Away      W  2.0
# 2   2024-08-31  12:30  Premier League   Matchweek 3  Sat  Home      D  1.0
# 1   2023-08-12  12:30  Premier League   Matchweek 1  Sat  Home      W  2.0
# 2   2023-08-21  20:00  Premier League   Matchweek 2  Mon  Away      W  1.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 52  2021-05-02  14:00  Premier League  Matchweek 34  Sun  Away      W  2.0
# 54  2021-05-09  19:00  Premier League  Matchweek 35  Sun  Home      W  3.0
# 55  2021-05-12  20:15  Premier League  Matchweek 36  Wed  Away      W  1.0
# 56  2021-05-19  19:00  Premier League  Matchweek 37  Wed  Away      W  3.0
# 57  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  2.0
#
#      ga         opponent  ...  match report  notes    sh  sot  dist   fk pk  \
# 0   0.0           Wolves  ...  Match Report    NaN  18.0  6.0  17.3  0.0  0
# 1   0.0      Aston Villa  ...  Match Report    NaN   9.0  4.0  18.8  0.0  0
# 2   1.0         Brighton  ...  Match Report    NaN  11.0  7.0  12.9  0.0  0
# 1   1.0  Nott'ham Forest  ...  Match Report    NaN  15.0  7.0  19.1  0.0  0
# 2   0.0   Crystal Palace  ...  Match Report    NaN  13.0  2.0  16.4  0.0  1
# ..  ...              ...  ...           ...    ...   ...  ...   ...  ... ..
# 52  0.0    Newcastle Utd  ...  Match Report    NaN  19.0  4.0  17.0  1.0  0
# 54  1.0        West Brom  ...  Match Report    NaN  15.0  7.0  19.7  1.0  0
# 55  0.0          Chelsea  ...  Match Report    NaN   5.0  2.0  20.7  0.0  0
# 56  1.0   Crystal Palace  ...  Match Report    NaN   6.0  3.0  14.2  0.0  0
# 57  0.0         Brighton  ...  Match Report    NaN  16.0  5.0  20.8  1.0  0
#
#    pkatt season     team
# 0      0   2025  Arsenal
# 1      0   2025  Arsenal
# 2      0   2025  Arsenal
# 1      0   2024  Arsenal
# 2      1   2024  Arsenal
# ..   ...    ...      ...
# 52     0   2021  Arsenal
# 54     0   2021  Arsenal
# 55     0   2021  Arsenal
# 56     0   2021  Arsenal
# 57     0   2021  Arsenal
#
# [155 rows x 28 columns]

# %%
# looking at data types in columns, as ML models only work with nums
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf               float64
# ga               float64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh               float64
# sot              float64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
# converting date to a date-time data type
# does not create a new date, just overwrites the current one
matches["date"] = pd.to_datetime(matches["date"])

# %%
# first predictor we are creating
# turning home/away into a numeric column (0 when away or 1 when home) so that it is quantifiable
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
# doing the same thing again here, but for opponents
# each team has its own
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
# again, doing the same with time
# focusing on just the hour to see if teams perform better during a specific time of day
# removing minutes as it is useless,
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
# converting the day of the week to a number, Monday starts at 0
matches["day_code"] = matches["date"].dt.dayofweek

# %%
# creating a target of what we are trying to predict, if the team won or not
# if result is a loss or a draw, it is a 0, a win is 1
matches["target"] = (matches["result"] == "W").astype("int")

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# creating a random forest classifier
# n_estimators is the number of decision trees we want to train
# min_samples_split is how many samples in a leaf of the decision tree
# random state means that we will get the same result when we rerun the decision tree

rf = RandomForestClassifier(n_estimators = 50, min_samples_split = 10, random_state = 1)

# %%
# training set of data is anything before 2024
train = matches[matches["date"] < '2024-01-01']

# %%
# rest set of data is anything after 2024
test = matches[matches["date"] >= '2024-01-01']

# %%
# things we will be fitting the data on
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
# fitting the model on said predictors
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
# using rf to train our model
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
# now we predict the results based on the predictores in the test data set
preds = rf.predict(test[predictors])

# %%
# package that looks at how accurate your model was
from sklearn.metrics import accuracy_score

# %%
# passing in our predicted vs actual results
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6518691588785047

# %%
# our accuracy is 65%, meaning that we predict a team would win, they would actually win 65%

# %%
# now we check in which results does our model fall short
combined = pd.DataFrame(dict(actual=test["target"], predictions=preds ))

# %%
# creating a crosstable (a 2-way table)
# creating a table that shows the actual vs predicted values
pd.crosstab(index = combined["actual"], columns = combined["predictions"])
# Out:
# predictions    0   1
# actual
# 0            216  51
# 1             98  63

# %%
# last table shows us that when we predicted a team to lose or draw (0), we were correct 2x as many times as we were wrong
# when we predict a team to win, we're barely more correct with predicting correct results
# since the focus of this model is to predict wins, we need to revisit the model

# %%
# importing a different package
# the reason for this is to look at the accuracy of a specific instance, in this case it will be the accuracy of predicting wins
# this is needed because we don't know the precision of what we are actually trying to measure
from sklearn.metrics import precision_score

# %%
# goes down 10%
precision_score(test["target"], preds)
# Out:
# 0.5526315789473685

# %%
# splitting into teams
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Arsenal")

# %%
# closed = left excludes the current row when making predictions, so that data of the game you are predicting does not leak
# have to drop rows with missing values

def rolling_averages(group, cols, new_cols):
  """
    Calculate the rolling average for specified columns over a 3-row window, excluding the current row.

    Parameters:
    -----------
    group : pd.DataFrame
        Input DataFrame containing the data to compute rolling averages on. Must include a 'date' column.

    cols : list of str
        List of column names for which the rolling averages will be calculated.

    new_cols : list of str
        List of new column names where the computed rolling averages will be stored.

    Returns:
    --------
    pd.DataFrame
        DataFrame with new columns containing rolling averages, excluding rows where these values
        cannot be calculated.
    """
  group = group.sort_values("date")
  rolling_stats = group[cols].rolling(3, closed = 'left').mean()
  group[new_cols] = rolling_stats
  group = group.dropna(subset = new_cols)
  return group

# %%
# columns that we will be creating rolling averages for
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]

# new columns that will contain all the calculated rolling averages
new_cols = [f"{c}_rolling" for c in cols]

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 50 2024-05-12  16:30  Premier League  Matchweek 37  Sun  Away      W  1.0
# 51 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      W  2.0
# 0  2024-08-17  15:00  Premier League   Matchweek 1  Sat  Home      W  2.0
# 1  2024-08-24  17:30  Premier League   Matchweek 2  Sat  Away      W  2.0
# 2  2024-08-31  12:30  Premier League   Matchweek 3  Sat  Home      D  1.0
#
#      ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 6   1.0    Sheffield Utd  ...         6       1    2.000000    1.333333
# 7   1.0  Manchester City  ...         5       0    1.666667    1.666667
# 9   1.0   Leicester City  ...         6       0    1.000000    1.666667
# 11  0.0   Manchester Utd  ...         6       1    0.666667    1.000000
# 13  3.0      Aston Villa  ...         6       0    0.333333    0.666667
# ..  ...              ...  ...       ...     ...         ...         ...
# 50  0.0   Manchester Utd  ...         6       1    3.666667    0.666667
# 51  1.0          Everton  ...         6       1    2.333333    0.666667
# 0   0.0           Wolves  ...         5       1    2.000000    0.333333
# 1   0.0      Aston Villa  ...         5       1    1.666667    0.333333
# 2   1.0         Brighton  ...         5       0    2.000000    0.333333
#
#    sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 6    8.000000    3.666667    14.633333   0.666667   0.000000       0.000000
# 7    5.666667    3.666667    15.366667   0.000000   0.000000       0.000000
# 9    7.000000    3.666667    16.566667   0.666667   0.000000       0.000000
# 11   9.666667    4.000000    16.566667   1.000000   0.000000       0.000000
# 13   9.666667    2.666667    19.333333   1.000000   0.333333       0.333333
# ..        ...         ...          ...        ...        ...            ...
# 50  20.000000    7.000000    14.866667   0.333333   0.333333       0.333333
# 51  14.666667    5.333333    13.900000   0.333333   0.333333       0.333333
# 0   20.333333    6.000000    13.833333   0.000000   0.333333       0.333333
# 1   18.333333    5.333333    14.933333   0.000000   0.000000       0.000000
# 2   17.666667    5.000000    16.733333   0.000000   0.000000       0.000000
#
# [152 rows x 41 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 43 2024-05-11  15:00  Premier League  Matchweek 37
#                         44 2024-05-19  16:00  Premier League  Matchweek 38
#                         0  2024-08-17  15:00  Premier League   Matchweek 1
#                         1  2024-08-25  14:00  Premier League   Matchweek 2
#                         3  2024-08-31  15:00  Premier League   Matchweek 3
#
#                             day venue result   gf   ga         opponent  ...  \
# team                                                                     ...
# Arsenal                 6   Sun  Home      W  2.0  1.0    Sheffield Utd  ...
#                         7   Sat  Away      L  0.0  1.0  Manchester City  ...
#                         9   Sun  Home      L  0.0  1.0   Leicester City  ...
#                         11  Sun  Away      W  1.0  0.0   Manchester Utd  ...
#                         13  Sun  Home      L  0.0  3.0      Aston Villa  ...
# ...                         ...   ...    ...  ...  ...              ...  ...
# Wolverhampton Wanderers 43  Sat  Home      L  1.0  3.0   Crystal Palace  ...
#                         44  Sun  Away      L  0.0  2.0        Liverpool  ...
#                         0   Sat  Away      L  0.0  2.0          Arsenal  ...
#                         1   Sun  Home      L  2.0  6.0          Chelsea  ...
#                         3   Sat  Away      D  1.0  1.0  Nott'ham Forest  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 6          6       1    2.000000    1.333333
#                         7          5       0    1.666667    1.666667
#                         9          6       0    1.000000    1.666667
#                         11         6       1    0.666667    1.000000
#                         13         6       0    0.333333    0.666667
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 43         5       0    1.000000    2.333333
#                         44         6       0    1.333333    3.000000
#                         0          5       0    0.666667    3.333333
#                         1          6       0    0.333333    2.333333
#                         3          5       0    0.666667    3.333333
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 6    8.000000    3.666667    14.633333   0.666667
#                         7    5.666667    3.666667    15.366667   0.000000
#                         9    7.000000    3.666667    16.566667   0.666667
#                         11   9.666667    4.000000    16.566667   1.000000
#                         13   9.666667    2.666667    19.333333   1.000000
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 43  10.000000    3.333333    15.966667   0.000000
#                         44   9.666667    4.666667    14.133333   0.000000
#                         0    6.666667    3.666667    14.200000   0.333333
#                         1    9.000000    4.333333    17.633333   0.666667
#                         3    8.333333    3.000000    19.133333   1.000000
#
#                            pk_rolling  pkatt_rolling
# team
# Arsenal                 6    0.000000       0.000000
#                         7    0.000000       0.000000
#                         9    0.000000       0.000000
#                         11   0.000000       0.000000
#                         13   0.333333       0.333333
# ...                               ...            ...
# Wolverhampton Wanderers 43   0.000000       0.000000
#                         44   0.000000       0.000000
#                         0    0.000000       0.000000
#                         1    0.000000       0.000000
#                         3    0.000000       0.000000
#
# [3016 rows x 41 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 43 2024-05-11  15:00  Premier League  Matchweek 37  Sat  Home      L  1.0
# 44 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Away      L  0.0
# 0  2024-08-17  15:00  Premier League   Matchweek 1  Sat  Away      L  0.0
# 1  2024-08-25  14:00  Premier League   Matchweek 2  Sun  Home      L  2.0
# 3  2024-08-31  15:00  Premier League   Matchweek 3  Sat  Away      D  1.0
#
#      ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 6   1.0    Sheffield Utd  ...         6       1    2.000000    1.333333
# 7   1.0  Manchester City  ...         5       0    1.666667    1.666667
# 9   1.0   Leicester City  ...         6       0    1.000000    1.666667
# 11  0.0   Manchester Utd  ...         6       1    0.666667    1.000000
# 13  3.0      Aston Villa  ...         6       0    0.333333    0.666667
# ..  ...              ...  ...       ...     ...         ...         ...
# 43  3.0   Crystal Palace  ...         5       0    1.000000    2.333333
# 44  2.0        Liverpool  ...         6       0    1.333333    3.000000
# 0   2.0          Arsenal  ...         5       0    0.666667    3.333333
# 1   6.0          Chelsea  ...         6       0    0.333333    2.333333
# 3   1.0  Nott'ham Forest  ...         5       0    0.666667    3.333333
#
#    sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 6    8.000000    3.666667    14.633333   0.666667   0.000000       0.000000
# 7    5.666667    3.666667    15.366667   0.000000   0.000000       0.000000
# 9    7.000000    3.666667    16.566667   0.666667   0.000000       0.000000
# 11   9.666667    4.000000    16.566667   1.000000   0.000000       0.000000
# 13   9.666667    2.666667    19.333333   1.000000   0.333333       0.333333
# ..        ...         ...          ...        ...        ...            ...
# 43  10.000000    3.333333    15.966667   0.000000   0.000000       0.000000
# 44   9.666667    4.666667    14.133333   0.000000   0.000000       0.000000
# 0    6.666667    3.666667    14.200000   0.333333   0.000000       0.000000
# 1    9.000000    4.333333    17.633333   0.666667   0.000000       0.000000
# 3    8.333333    3.000000    19.133333   1.000000   0.000000       0.000000
#
# [3016 rows x 41 columns]

# %%
# assigning indexes to rows so that each row has a unique index
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
  train = data[data["date"] < '2024-01-01']
  test = data[data["date"] >= '2024-01-01']
  rf.fit(train[predictors], train["target"])
  preds = rf.predict(test[predictors])
  combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
  precision = precision_score(test["target"], preds)
  return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
# increase of 7%
precision
# Out:
# 0.6271186440677966

# %%
combined
# Out:
#       actual  predicted
# 131        1          0
# 132        1          1
# 133        1          0
# 134        1          1
# 135        1          1
# ...      ...        ...
# 3011       0          0
# 3012       0          0
# 3013       0          0
# 3014       0          0
# 3015       0          0
#
# [425 rows x 2 columns]

# %%
# issue with combined table you cannot table where the mistakes are, just given indexes
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index = True, right_index = True)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 131        1          0 2024-01-20                  Arsenal   Crystal Palace
# 132        1          1 2024-01-30                  Arsenal  Nott'ham Forest
# 133        1          0 2024-02-04                  Arsenal        Liverpool
# 134        1          1 2024-02-11                  Arsenal         West Ham
# 135        1          1 2024-02-17                  Arsenal          Burnley
# ...      ...        ...        ...                      ...              ...
# 3011       0          0 2024-05-11  Wolverhampton Wanderers   Crystal Palace
# 3012       0          0 2024-05-19  Wolverhampton Wanderers        Liverpool
# 3013       0          0 2024-08-17  Wolverhampton Wanderers          Arsenal
# 3014       0          0 2024-08-25  Wolverhampton Wanderers          Chelsea
# 3015       0          0 2024-08-31  Wolverhampton Wanderers  Nott'ham Forest
#
#      result
# 131       W
# 132       W
# 133       W
# 134       W
# 135       W
# ...     ...
# 3011      L
# 3012      L
# 3013      L
# 3014      L
# 3015      D
#
# [425 rows x 6 columns]

# %%
# our algorithm might make different predictions on the same game
# if Villa play City at home, it might predict Villa to beat City at home
# whereas when it predicts the game for City, they might predict them to beat despite being away
# we need to unify the predictions

# %%
class MissingDict(dict):
  __missing__ = lambda self, key: key

map_values = {
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Newcastle United": "Newcastle Utd",
    "Tottenham Hotspur": "Tottenham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves"
}
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 131        1          0 2024-01-20                  Arsenal   Crystal Palace
# 132        1          1 2024-01-30                  Arsenal  Nott'ham Forest
# 133        1          0 2024-02-04                  Arsenal        Liverpool
# 134        1          1 2024-02-11                  Arsenal         West Ham
# 135        1          1 2024-02-17                  Arsenal          Burnley
# ...      ...        ...        ...                      ...              ...
# 3011       0          0 2024-05-11  Wolverhampton Wanderers   Crystal Palace
# 3012       0          0 2024-05-19  Wolverhampton Wanderers        Liverpool
# 3013       0          0 2024-08-17  Wolverhampton Wanderers          Arsenal
# 3014       0          0 2024-08-25  Wolverhampton Wanderers          Chelsea
# 3015       0          0 2024-08-31  Wolverhampton Wanderers  Nott'ham Forest
#
#      result new_team
# 131       W  Arsenal
# 132       W  Arsenal
# 133       W  Arsenal
# 134       W  Arsenal
# 135       W  Arsenal
# ...     ...      ...
# 3011      L   Wolves
# 3012      L   Wolves
# 3013      L   Wolves
# 3014      L   Wolves
# 3015      D   Wolves
#
# [425 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           1            0 2024-01-20                  Arsenal
# 1           1            1 2024-01-30                  Arsenal
# 2           1            0 2024-02-04                  Arsenal
# 3           1            1 2024-02-11                  Arsenal
# 4           1            1 2024-02-17                  Arsenal
# ..        ...          ...        ...                      ...
# 378         0            0 2024-05-11  Wolverhampton Wanderers
# 379         0            0 2024-05-19  Wolverhampton Wanderers
# 380         0            0 2024-08-17  Wolverhampton Wanderers
# 381         0            0 2024-08-25  Wolverhampton Wanderers
# 382         0            0 2024-08-31  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0     Crystal Palace        W    Arsenal         0            0
# 1    Nott'ham Forest        W    Arsenal         0            0
# 2          Liverpool        W    Arsenal         0            1
# 3           West Ham        W    Arsenal         0            0
# 4            Burnley        W    Arsenal         0            0
# ..               ...      ...        ...       ...          ...
# 378   Crystal Palace        L     Wolves         1            1
# 379        Liverpool        L     Wolves         1            1
# 380          Arsenal        L     Wolves         1            1
# 381          Chelsea        L     Wolves         1            0
# 382  Nott'ham Forest        D     Wolves         0            1
#
#                 team_y opponent_y result_y         new_team_y
# 0       Crystal Palace    Arsenal        L     Crystal Palace
# 1    Nottingham Forest    Arsenal        L  Nottingham Forest
# 2            Liverpool    Arsenal        L          Liverpool
# 3      West Ham United    Arsenal        L           West Ham
# 4              Burnley    Arsenal        L            Burnley
# ..                 ...        ...      ...                ...
# 378     Crystal Palace     Wolves        W     Crystal Palace
# 379          Liverpool     Wolves        W          Liverpool
# 380            Arsenal     Wolves        W            Arsenal
# 381            Chelsea     Wolves        W            Chelsea
# 382  Nottingham Forest     Wolves        D  Nottingham Forest
#
# [383 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    67
# 0    38
# Name: count, dtype: int64

# %%
# 64% accuracy
67/105
# Out:
# 0.638095238095238
